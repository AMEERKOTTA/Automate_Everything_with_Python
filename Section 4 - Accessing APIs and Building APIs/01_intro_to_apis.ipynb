# %%
API_key = "fdbb3f1a36d14ab181872d33fd6c5737"

# %%
import requests

r = requests.get("https://newsapi.org/v2/everything?qInTitle=stock%20market&from=2023-1-08&to=2023-1-09&sortBy=popularity&language=en&apiKey=890603a55bfa47048e4490069ebee18c")

content = r.json()
print(type(content))

print(content.keys())
print(content)

print(content["totalResults"])
print(content["status"])
# Out:
# <class 'dict'>
# dict_keys(['status', 'totalResults', 'articles'])
# ...

# %%
from newsapi import NewsApiClient

# %%
# Init
newsapi = NewsApiClient(api_key='fdbb3f1a36d14ab181872d33fd6c5737')

# /v2/top-headlines
top_headlines = newsapi.get_top_headlines(q='bitcoin',
                                          sources='bbc-news,the-verge',
                                          category='business',
                                          language='en',
                                          country='us')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-649447932b7e> in <module>
#       3
#       4 # /v2/top-headlines
# ----> 5 top_headlines = newsapi.get_top_headlines(q='bitcoin',
#       6                                           sources='bbc-news,the-verge',
#       7                                           category='business',
#
# D:\Anaconda\lib\site-packages\newsapi\newsapi_client.py in get_top_headlines(self, q, qintitle, sources, language, country, category, page_size, page)
#     103         # Sources
#     104         if (sources is not None) and ((country is not None) or (category is not None)):
# --> 105             raise ValueError("cannot mix country/category param with sources param.")
#     106
#     107         # Sources
#
# ValueError: cannot mix country/category param with sources param.

# %%
# /v2/everything
all_articles = newsapi.get_everything(q='bitcoin',
                                      sources='bbc-news,the-verge',
                                      domains='bbc.co.uk,techcrunch.com',
                                      from_param='2023-01-01',
                                      to='2023-01-09',
                                      language='en',
                                      sort_by='relevancy',
                                      page=2)
all_articles
# Out:
# {'status': 'ok', 'totalResults': 3, 'articles': []}
